# %%
# !python --version
# Out:
# Python 3.12.12

# %%
# !wget -O miniconda.sh https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x miniconda.sh
# !bash ./miniconda.sh -b -f -p /usr/local

# Accept TOS
# !/usr/local/bin/conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !/usr/local/bin/conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r

# Create Python 3.10 env
# !/usr/local/bin/conda create -y -n py310 python=3.10 jupyter
# Out:
# --2025-11-15 04:44:27--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 157891003 (151M) [application/octet-stream]
# Saving to: ‘miniconda.sh’
#
# miniconda.sh        100%[===================>] 150.58M  40.5MB/s    in 3.7s
#
# 2025-11-15 04:44:31 (40.8 MB/s) - ‘miniconda.sh’ saved [157891003/157891003]
#
# PREFIX=/usr/local
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
# ...

# %%
# !curl -fsSL https://code-server.dev/install.sh | sh -s -- --dry-run
# Out:
# Ubuntu 22.04.4 LTS
# Installing v4.105.1 of the amd64 deb package from GitHub.
#
# + mkdir -p ~/.cache/code-server
# + curl -#fL -o ~/.cache/code-server/code-server_4.105.1_amd64.deb.incomplete -C - https://github.com/coder/code-server/releases/download/v4.105.1/code-server_4.105.1_amd64.deb
# + mv ~/.cache/code-server/code-server_4.105.1_amd64.deb.incomplete ~/.cache/code-server/code-server_4.105.1_amd64.deb
# + dpkg -i ~/.cache/code-server/code-server_4.105.1_amd64.deb
#
# deb package has been installed.
#
# To have systemd start code-server now and restart on boot:
#   sudo systemctl enable --now code-server@$USER
# Or, if you don't want/need a background service you can run:
#   code-server
#
# Deploy code-server for your team with Coder: https://github.com/coder/coder

# %%
# !curl -fsSL https://code-server.dev/install.sh | sh
# Out:
# Ubuntu 22.04.4 LTS
# Installing v4.105.1 of the amd64 deb package from GitHub.
#
# + mkdir -p ~/.cache/code-server
# + curl -#fL -o ~/.cache/code-server/code-server_4.105.1_amd64.deb.incomplete -C - https://github.com/coder/code-server/releases/download/v4.105.1/code-server_4.105.1_amd64.deb
# ######################################################################## 100.0%
# + mv ~/.cache/code-server/code-server_4.105.1_amd64.deb.incomplete ~/.cache/code-server/code-server_4.105.1_amd64.deb
# + dpkg -i ~/.cache/code-server/code-server_4.105.1_amd64.deb
# Selecting previously unselected package code-server.
# (Reading database ... 121703 files and directories currently installed.)
# Preparing to unpack .../code-server_4.105.1_amd64.deb ...
# Unpacking code-server (4.105.1) ...
# Setting up code-server (4.105.1) ...
#
# deb package has been installed.
#
# To have systemd start code-server now and restart on boot:
#   sudo systemctl enable --now code-server@$USER
# ...

# %%
# !sudo systemctl enable --now code-server@$USER
# Out:
# Failed to enable code-server@.service, destination unit default.target is a non-template unit.

# %%
# !which code-server
# !code-server --version
# Out:
# /bin/bash: line 1: code-server: command not found

# %%
# !mkdir -p ~/.config/code-server

# %%
import os
os.system("""cat << 'EOF' > ~/.config/code-server/config.yaml
bind-addr: 0.0.0.0:9000
auth: none
cert: false
EOF
""")
# Out:
# 0

# %%
# !code-server --config ~/.config/code-server/config.yaml &
# Out:
# /bin/bash: line 1: code-server: command not found

# %%
# !echo "" > /root/.jupyter/jupyter_server_config.py
# !echo "" > /root/.jupyter/jupyter_notebook_config.py

# %%
# !/usr/local/bin/conda run -n py310 bash -c \
"JUPYTER_CONFIG_DIR=/usr/local/envs/py310/jupyter_config \
python -m jupyterlab --ServerApp.token='' --ServerApp.password='' --no-browser --port=8888" &
# Out:
# [W 2025-11-15 04:57:03.072 ServerApp] ServerApp.token config is deprecated in 2.0. Use IdentityProvider.token.
# [C 2025-11-15 04:57:03.075 ServerApp] Bad config encountered during initialization: The 'login_handler_class' trait of <jupyter_server.serverapp.ServerApp object at 0x79b40aa56140> instance must be a type, but 'google.colab._login_handler.ColabLoginHandler' could not be imported
#
# ERROR conda.cli.main_run:execute(127): `conda run bash -c JUPYTER_CONFIG_DIR=/usr/local/envs/py310/jupyter_config  python -m jupyterlab --ServerApp.token='' --ServerApp.password='' --no-browser --port=8888` failed. (See above for error)

# %%
# !wget -q -O ngrok.zip https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-stable-linux-amd64.zip
# !unzip -o ngrok.zip
# !./ngrok authtoken 35V4kZIwVt9ONHjLmooI9uA3UoI_5Pr2M2JdWZrdQV8Jcb1mK
# Out:
# Archive:  ngrok.zip
#   inflating: ngrok

# %%
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !/usr/local/bin/conda run -n py310 jupyter notebook --NotebookApp.token='' --NotebookApp.password='' --port=8888 --no-browser &
# Out:
# [C 2025-11-15 04:48:20.302 ServerApp] Bad config encountered during initialization: The 'login_handler_class' trait of <jupyter_server.serverapp.ServerApp object at 0x7db9b18dc160> instance must be a type, but 'google.colab._login_handler.ColabLoginHandler' could not be imported
#
# ERROR conda.cli.main_run:execute(127): `conda run jupyter notebook --NotebookApp.token= --NotebookApp.password= --port=8888 --no-browser` failed. (See above for error)

# %%
import os, sys

os.environ["PYTHONEXECUTABLE"] = py_path
os.environ["PATH"] = f"/usr/local/envs/py310/bin:" + os.environ["PATH"]

print("Python interpreter is now:", sys.executable)
# Out:
# Python interpreter is now: /usr/bin/python3

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
# !ls
# Out:
# miniconda.sh  sample_data

# %%
os.system("""cat << 'EOF' > /usr/local/bin/colab_python310
#!/bin/bash
source /usr/local/etc/profile.d/conda.sh
conda activate py310
python "\$@"
EOF

chmod +x /usr/local/bin/colab_python310
""")
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\$'
# <>:5: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipython-input-2465191047.py:5: SyntaxWarning: invalid escape sequence '\$'
#   python "\$@"
# 0

# %%
import os
os.environ["PYTHONSTARTUP"] = "/usr/local/bin/colab_python310"

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# ### Install using pip

# %%
# !pip install colabcode
from colabcode import ColabCode
# !wget -q -O ngrok.zip https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-stable-linux-amd64.zip
# !unzip -o ngrok.zip
# !./ngrok authtoken 35V4dWk1P6lCZEFNcnAKCWoGuR6_7VznL3y9mknfvFSbSMava
ColabCode(port=10000)
# Out:
# ...
# Archive:  ngrok.zip
#   inflating: ngrok
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# WARNING:pyngrok.process.ngrok:t=2025-11-15T05:24:14+0000 lvl=warn msg="invalid tunnel configuration" pg=/api/tunnels id=3a2a017457d5eb2b err="yaml: unmarshal errors:\n  line 1: field options not found in type config.HTTPv2Tunnel"
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     628     try:
# --> 629         response = urlopen(request, encoded_data, timeout)
#     630         response_data = response.read().decode("utf-8")
#
# /usr/lib/python3.12/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214         opener = _opener
# --> 215     return opener.open(url, data, timeout)
#     216
#
# ...

# %%
vscode_colab.login()
# Out:
# 2025-11-15 05:14:09 | INFO     | vscode_colab.server:download_vscode_cli:74 - Downloading VS Code CLI (cli-alpine-x64) to /content/vscode_cli_alpine_x64.tar.gz...
# 2025-11-15 05:14:09 | INFO     | vscode_colab.server:download_vscode_cli:87 - VS Code CLI tarball downloaded. Extracting...
# 2025-11-15 05:14:10 | INFO     | vscode_colab.server:download_vscode_cli:171 - VS Code CLI setup successful. Executable at: '/content/code'.
# 2025-11-15 05:14:10 | INFO     | vscode_colab.server:_login:220 - Initiating VS Code Tunnel login with command: /content/code tunnel user login --provider github
# 2025-11-15 05:14:10 | INFO     | vscode_colab.server:_login:254 - Monitoring login process output for GitHub authentication URL and code...
# 2025-11-15 05:14:10 | INFO     | vscode_colab.server:_login:272 - Detected authentication URL: https://github.com/login/device
# 2025-11-15 05:14:10 | INFO     | vscode_colab.server:_login:278 - Detected authentication code: 079B-24A8
# ...

# %%
import vscode_colab

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# ### colab ssh

# %%
# !pip install colab_ssh --upgrade

# %%
import colab_ssh
from colab_ssh import launch_ssh

# Replace 'YOUR_NGROK_TOKEN' with your actual ngrok token
# Replace 'YOUR_PASSWORD' with a strong password for your SSH connection
launch_ssh(ngrokToken="35V4dWk1P6lCZEFNcnAKCWoGuR6_7VznL3y9mknfvFSbSMava", password="hellotunnel")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3326728035.py in <cell line: 0>()
#       4 # Replace 'YOUR_NGROK_TOKEN' with your actual ngrok token
#       5 # Replace 'YOUR_PASSWORD' with a strong password for your SSH connection
# ----> 6 launch_ssh(ngrokToken="35V4dWk1P6lCZEFNcnAKCWoGuR6_7VznL3y9mknfvFSbSMava", password="hellotunnel")
#
# TypeError: launch_ssh() got an unexpected keyword argument 'ngrokToken'
