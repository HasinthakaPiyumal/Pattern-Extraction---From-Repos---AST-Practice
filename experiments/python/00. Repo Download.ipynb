# %%
l = """https://github.com/dipampaul17/AgentGuard
https://github.com/truffle-ai/dexto
https://github.com/traceroot-ai/traceroot
https://github.com/lastmile-ai/mcp-agent/tree/main/examples/usecases/mcp_realtor_agent
https://github.com/fal-ai-community/video-starter-kit
https://github.com/plandex-ai/plandex
https://github.com/matiasmolinas/evolving-agents
https://github.com/Operative-Sh/web-eval-agent
https://github.com/TabbyML/tabby
https://github.com/1rvinn/mindpalace
https://github.com/kody-w/Copilot-Agent-365
https://github.com/KittenML/KittenTTS
https://github.com/JackHopkins/factorio-learning-environment
https://github.com/DIYer22/discrete_distribution_networks
https://github.com/nari-labs/dia
https://github.com/EpicenterHQ/epicenter/tree/main/apps/whispering
https://github.com/KoljaB/RealtimeVoiceChat
https://github.com/circlemind-ai/fast-graphrag
https://github.com/onlook-dev/onlook
https://github.com/codelion/pts
https://github.com/brianmg/voynich-nlp-analysis
https://github.com/abhinavxd/libredesk
https://github.com/browserbase/stagehand
https://github.com/lastmile-ai/mcp-agent"""
l = l.split("\n")

# %%
# !mkdir -p repos

# %%
import os

for url in l:
    repo_name = url.split("/")[-1]
    dest_path = os.path.join("repos", repo_name)
    if not os.path.exists(dest_path):
        print(f"Cloning {url} into {dest_path}")
        os.system(f"git clone {url} {dest_path}")
    else:
        print(f"Repository {repo_name} already exists. Skipping...")
# Out:
# Cloning https://github.com/dipampaul17/AgentGuard into repos/AgentGuard
# Cloning into 'repos/AgentGuard'...
# Cloning https://github.com/truffle-ai/dexto into repos/dexto
# Cloning into 'repos/dexto'...
# Cloning https://github.com/traceroot-ai/traceroot into repos/traceroot
# Cloning into 'repos/traceroot'...
# Cloning https://github.com/lastmile-ai/mcp-agent/tree/main/examples/usecases/mcp_realtor_agent into repos/mcp_realtor_agent
# Cloning into 'repos/mcp_realtor_agent'...
# fatal: repository 'https://github.com/lastmile-ai/mcp-agent/tree/main/examples/usecases/mcp_realtor_agent/' not found
# Cloning into 'repos/video-starter-kit'...
# Cloning https://github.com/fal-ai-community/video-starter-kit into repos/video-starter-kit
# Cloning https://github.com/plandex-ai/plandex into repos/plandex
# Cloning into 'repos/plandex'...
# Cloning https://github.com/matiasmolinas/evolving-agents into repos/evolving-agents
# Cloning into 'repos/evolving-agents'...
# Cloning https://github.com/Operative-Sh/web-eval-agent into repos/web-eval-agent
# Cloning into 'repos/web-eval-agent'...
# Cloning https://github.com/TabbyML/tabby into repos/tabby
# Cloning into 'repos/tabby'...
# Cloning https://github.com/1rvinn/mindpalace into repos/mindpalace
# Cloning into 'repos/mindpalace'...
# Cloning https://github.com/kody-w/Copilot-Agent-365 into repos/Copilot-Agent-365
# Cloning into 'repos/Copilot-Agent-365'...
# Cloning https://github.com/KittenML/KittenTTS into repos/KittenTTS
# Cloning into 'repos/KittenTTS'...
# Cloning https://github.com/JackHopkins/factorio-learning-environment into repos/factorio-learning-environment
# Cloning into 'repos/factorio-learning-environment'...
# Cloning https://github.com/DIYer22/discrete_distribution_networks into repos/discrete_distribution_networks
# Cloning into 'repos/discrete_distribution_networks'...
# Cloning https://github.com/nari-labs/dia into repos/dia
# Cloning into 'repos/dia'...
# Cloning https://github.com/EpicenterHQ/epicenter/tree/main/apps/whispering into repos/whispering
# Cloning into 'repos/whispering'...
# fatal: repository 'https://github.com/EpicenterHQ/epicenter/tree/main/apps/whispering/' not found
# Cloning into 'repos/RealtimeVoiceChat'...
# Cloning https://github.com/KoljaB/RealtimeVoiceChat into repos/RealtimeVoiceChat
# Cloning https://github.com/circlemind-ai/fast-graphrag into repos/fast-graphrag
# Cloning into 'repos/fast-graphrag'...
# Cloning https://github.com/onlook-dev/onlook into repos/onlook
# Cloning into 'repos/onlook'...
# Cloning https://github.com/codelion/pts into repos/pts
# Cloning into 'repos/pts'...
# Cloning https://github.com/brianmg/voynich-nlp-analysis into repos/voynich-nlp-analysis
# Cloning into 'repos/voynich-nlp-analysis'...
# Cloning https://github.com/abhinavxd/libredesk into repos/libredesk
# Cloning into 'repos/libredesk'...
# Cloning https://github.com/browserbase/stagehand into repos/stagehand
# Cloning into 'repos/stagehand'...
# Cloning https://github.com/lastmile-ai/mcp-agent into repos/mcp-agent
# Cloning into 'repos/mcp-agent'...
